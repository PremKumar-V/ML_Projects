# %% [markdown]
# # New York Fare Price Prediction
#
# ## Outline
# - Prepare Notebook
# - Load Dataset
# - Explore and Preprocess Dataset
# - Config GPU
# - Linear Model
#     - Defining Our Model
#     - Training Our Model
#     - Evaluation
#     - Testing
# - Hypothesis
#
# - Testing with scaling
