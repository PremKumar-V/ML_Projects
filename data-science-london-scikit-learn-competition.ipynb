# %% [markdown]
# # Data Science London Scikit-learn Competition
#
# In this Notebook I will practice Data Science Competition. With provided Dataset, I will solve the problem by using sklearn

# %%
import numpy as np
import pandas as pd

import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report

# %%
DATA_FOLDER_PATH = '/kaggle/input/data-science-london-scikit-learn/'

# %%
trainDf = pd.read_csv(DATA_FOLDER_PATH + 'train.csv')
trainDf.head(1)
# Out:
#    0.29940251144353242  -1.2266241875260637  1.4984250500215328  \
# 0            -1.174176             0.332157            0.949919
#
#    -1.1761503610375272  5.2898525545597037  0.20829711393323402  \
# 0            -1.285328            2.199061            -0.151268
#
#    2.4044983672405826  1.5945062220589785  -0.051608163273514231  \
# 0           -0.427039            2.619246              -0.765884
#
#    0.66323431039687908  ...  -0.85046544625016463  -0.62298999638261954  \
# 0             -0.09378  ...              -0.81975              0.012037
#
#    -1.8330573433160038  0.29302438506869571  3.5526813410266507  \
# 0             2.038836             0.468579           -0.517657
#
#    0.71761099417552265  3.3059719748508889  -2.7155588147154619  \
# 0             0.422326            0.803699             1.213219
#
#    -2.6824085866346223  0.10105047232890663
# 0             1.382932            -1.817761
#
# [1 rows x 40 columns]

# %%
trainLabels = pd.read_csv(DATA_FOLDER_PATH + 'trainLabels.csv')
trainLabels.head(1)
# Out:
#    1
# 0  0

# %%
plt.figure(figsize = (12, 8))
sns.heatmap(trainDf.corr(), cbar = True, xticklabels = False, yticklabels = False)
plt.show()

# %%
trainDf.shape[0] == trainLabels.shape[0]
# Out:
# True
